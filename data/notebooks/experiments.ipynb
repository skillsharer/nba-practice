# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import train_test_split, GridSearchCV
from matplotlib import pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore', drop="first")

# %%
# Helper functions
def box_plot(feature_col, outcome_col, title=""):
    assert len(feature_col) == len(outcome_col)
    groups = [g.values for _, g in feature_col.groupby(outcome_col)]
    labels = list(feature_col.groupby(outcome_col).groups.keys())

    plt.figure(figsize=(8, 6))
    plt.boxplot(groups, tick_labels=labels)
    plt.title(title)
    plt.ylabel(feature_col.name)
    plt.xlabel(outcome_col.name)
    plt.show()

def histogram_plot(feature):
    plt.figure(figsize=(6, 3))
    lower = feature.quantile(0.01)
    upper = feature.quantile(0.99)
    plt.hist(feature, bins="auto", range=(lower, upper))

    skewness=feature.skew()
    kurtosis=feature.kurt()
    plt.title(feature.name)
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.text(0.95, 0.95, f"Skewness: {skewness:.2f}\nKurtosis: {kurtosis:.2f}", transform=plt.gca().transAxes, ha="right", va="top")
    plt.show()

def bar_plot(feature):
    counts = feature.value_counts().sort_index()
    plt.figure(figsize=(6, 3))
    plt.bar(counts.index.astype(str), counts.values)
    plt.title(feature.name)
    plt.xlabel("Category")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

def scatter_plot(feature1, feature2):
    assert len(feature1) == len(feature2)
    plt.scatter(feature1, feature2)
    plt.show()

def categorical_plot(categories, rates, title):
    plt.figure()
    plt.bar(categories, rates)
    plt.title(title)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

def plot_pred_vs_true(y_test, preds):
    MIN_VALUE = 0
    MAX_VALUE = max(y_test)
    plt.figure(figsize=(8, 8))
    plt.scatter(y_test, preds)
    plt.plot([MIN_VALUE, MAX_VALUE], [MIN_VALUE, MAX_VALUE], '--k', label="Correct prediction")

    plt.title("Predicted vs. True Plot")
    plt.xlabel('True Price')
    plt.ylabel('Predicted Price')
    plt.legend()
    plt.tight_layout()

def plot_residual(y_test, preds):
    residuals = y_test - preds
    plt.figure(figsize=(8, 8))
    plt.xlabel('Price')
    plt.ylabel('Residuals')
    plt.title('Residual Plot')
    plt.scatter(preds, residuals)
    plt.axhline(0, linestyle="--")

def get_z_score_scale(dataset, feature_name):
    feature = list(dataset[feature_name])
    mu = np.mean(feature)
    std = np.std(feature)
    return mu, std

def z_score_scale(dataset, feature_name, mu, std):
    dataset[feature_name] = [round((i - mu) / std, 2) for i in dataset[feature_name]]

# Helper functions - Data imputation:
def get_mode(dataset, feature_name):
    mode = dataset[feature_name].mode()
    return mode.iloc[0] if not mode.empty else "unknown"

def get_mean(dataset, feature_name):
    return round(np.nanmean(dataset[feature_name]), 1)

def fill_value(dataset, feature_name, value):
    dataset[feature_name] = dataset[feature_name].fillna(value)

# Helper functions - Conversion
def category_to_num(dataset, feature_name):
    feature = list(dataset[feature_name])
    elements = set(feature)
    
    categories = {}
    for i, e in enumerate(elements):
        if not categories.get(e):
            categories[e] = float(i)

    for i, e in enumerate(feature):
        feature[i] = categories[e]
    
    dataset[feature_name] = feature

def remove_row_due_missing_element(dataset, feature_name):
    return dataset.dropna(subset=[feature_name])

def one_hot_encode_train_test(X_train, X_test, feature_name):
    train_feature = X_train[[feature_name]]
    test_feature = X_test[[feature_name]]

    encoder.fit(train_feature)

    encoded_columns = encoder.get_feature_names_out([feature_name])

    train_encoded = encoder.transform(train_feature)
    test_encoded = encoder.transform(test_feature)

    train_encoded_df = pd.DataFrame(train_encoded, columns=encoded_columns, index=X_train.index)
    test_encoded_df = pd.DataFrame(test_encoded, columns=encoded_columns, index=X_test.index)

    X_train = pd.concat([X_train.drop(columns=[feature_name]), train_encoded_df], axis=1)

    X_test = pd.concat([X_test.drop(columns=[feature_name]), test_encoded_df], axis=1)

    return X_train, X_test

# %%
def log_scale(feature):
    return np.log1p(feature)

def standard_scale(feature, mu=None, std=None):
    if mu == None or std == None:
        mu = np.mean(feature)
        std = np.std(feature)
    feature = [(i - mu) / std for i in feature]
    return feature, mu, std
 
def robust_scale(feature, median=None, iqr=None):
    if median == None or iqr == None:
        q1 = feature.quantile(0.25)
        median = feature.quantile(0.50)
        q3 = feature.quantile(0.75)
        iqr = q3 - q1
    if iqr == 0:
        raise ValueError("IQR is 0, Robust scaler cannot scale this feature")
    feature = (feature - median) / iqr
    return feature, median, iqr

# %%
def precision(y_test, y_true):
    assert len(y_test) == len(y_true)
    TP, FP, FN, TN = 0, 0, 0, 0
    for y_hat, y in zip(y_test, y_true):
        if y_hat == "yes" and y == "yes":
            TP += 1
        elif y_hat == "yes" and y == "no":
            FP += 1
        elif y_hat == "no" and y == "yes":
            FN += 1
        else:
            TN += 1
    precision = TP / (TP + FP)
    return precision

def recall(y_test, y_true):
    assert len(y_test) == len(y_true)
    TP, FP, FN, TN = 0, 0, 0, 0
    for y_hat, y in zip(y_test, y_true):
        if y_hat == "yes" and y == "yes":
            TP += 1
        elif y_hat == "yes" and y == "no":
            FP += 1
        elif y_hat == "no" and y == "yes":
            FN += 1
        else:
            TN += 1
    recall = TP / (TP + FN)
    return recall

# %%
class ModelHandler:

    def __init__(self):
        self.model = LogisticRegression(max_iter=1000)

    def predict(self, probs, threshold):
        preds = []
        for _, p in enumerate(probs):
            if p[1] >= threshold:
                preds.append('yes')
            else:
                preds.append('no')
        return preds

# %%
dataset = pd.read_csv("../bank-full.csv", sep=";")
dataset = dataset.drop(columns=["duration"])
independent_variables = dataset.drop(columns=["y"])
dependent_variable = dataset["y"]
seed = 42
test_size = 0.2
shuffle = True

# %%
X_train, X_test, y_train, y_test = train_test_split(independent_variables, dependent_variable, random_state=seed, test_size=test_size, shuffle=shuffle, stratify=dependent_variable)

# %%
categorical_features = X_train.select_dtypes(include=["object", "str"]).columns
numerical_features = X_train.select_dtypes(include=["number"]).columns

# %%
categorical_features
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome'],
#       dtype='str')

# %%
numerical_features
# Out:
# Index(['age', 'balance', 'day', 'campaign', 'pdays', 'previous'], dtype='str')

# %%
# We can easily one-hot encode all categorical features.
for f in categorical_features:
    X_train, X_test = one_hot_encode_train_test(X_train=X_train, X_test=X_test, feature_name=str(f))

# %%
# For numerical features, first I need to visualize their distribution.
for f in numerical_features:
    histogram_plot(X_train[str(f)])

# %%
# Pdays misleading here. -1 has different semantic meaning compared to the rest. The best would be to fix this feature semantic meaning. We already have 'previous' feature which contains
# the number of previous contacts, therefore we can't swap -1 to 0 if there is 0 in the feature.

# lets check that first:
print((dataset["pdays"] == 0).sum())

# There is no any 0 in the dataset, so we can avoid collision to an existing value in the dataset.
for df in [X_train, X_test]:
    df["pdays"] = df["pdays"].replace(-1, 0)
histogram_plot(X_train["pdays"])
bar_plot(X_train["previous"])
# Out:
# 0

# %%
# Which features are roughly symmetric, which are skewed, and which have heavy tails/outliers? Deciding these will help to decide the scalers.
# roughly simmetric: day, age
# skewed: balance, campaign, previous
# heavy outliers: balance
# special: pdays

# %%
# Age: Does not have heavy outliers, therefore standardscaler is good.
# Balance: It has huge outliers. Also there are negative balances, but its not so heavily skewed there. To reduce the outlier factor, I would use robust scaler. 
# We need those outliers, because those are not anomalies.
# Day: Days have equal meanings, therefore standard scaler is good.
# Campaign: Many elements around zero, one, two, three are present, therefore if standardscaler using mean and std, the 16 value would misalign. Therefore we need robust scaler.
# Previous: Robust scaler cannot be used here, due to heavy zero value amount. I will use log1p.
# PDays: Log scaling -> close gaps are more meaningful than later ones. Then maybe standard scaler if needed.

# %%
scales = {}
for f in ["age", "day"]:
    X_train[f], mu, std = standard_scale(X_train[f])
    scales[f] = (mu, std)

for f in ["balance", "campaign"]:
    X_train[f], median, iqr = robust_scale(X_train[f])
    scales[f] = (median, iqr)

X_train["previous"] = log_scale(X_train["previous"])
X_train["pdays"] = log_scale(X_train["pdays"])

X_test["previous"] = log_scale(X_test["previous"])
X_test["pdays"] = log_scale(X_test["pdays"])

# %%
for f in ["age", "day"]:
    scale = scales[f]
    mu, std = scale[0], scale[1]
    X_test[f], _, _ = standard_scale(X_test[f], mu=mu, std=std)

for f in ["balance", "campaign"]:
    scale = scales[f]
    median, iqr = scale[0], scale[1]
    X_test[f], _, _ = robust_scale(X_test[f], median=median, iqr=iqr)

# %%
# Checks before train
print(X_train.isna().sum().sum())
print(X_test.isna().sum().sum())
print(X_train.shape, X_test.shape)
# Out:
# 0
# 0
# (36168, 41) (9043, 41)

# %%
# Train with logistic regression
model_handler = ModelHandler()
model_handler.model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
preds = model_handler.model.predict(X_test)
sum(preds == y_test) / len(y_test)
# Out:
# 0.8935087913303107

# %%
# Accuracy is misleading here, because we have class imbalance. I need to check precision and recall.
# Recall is important, because we can loose potential subscribers, however if precision is too low, then we introduce many false positives. False positive
# here means that we target many customers which we think could subscribe but they won't and then we waste business resources.
prec = precision(preds, y_test)
rec = recall(preds, y_test)
print(prec, rec)
# Out:
# 0.6655052264808362 0.18052930056710775

# %%
# https://www.geeksforgeeks.org/machine-learning/understanding-the-predictproba-function-in-scikit-learns-svc/
# Get probability estimates for the test set
probabilities = model_handler.model.predict_proba(X_test)

# Display the probability estimates
for i, prob in enumerate(probabilities):
    print(f"Sample {i+1}: Class 0 Probability = {prob[0]:.4f}, Class 1 Probability = {prob[1]:.4f}")
# Out:
# Sample 1: Class 0 Probability = 0.9867, Class 1 Probability = 0.0133
# Sample 2: Class 0 Probability = 0.9744, Class 1 Probability = 0.0256
# Sample 3: Class 0 Probability = 0.9643, Class 1 Probability = 0.0357
# Sample 4: Class 0 Probability = 0.9827, Class 1 Probability = 0.0173
# Sample 5: Class 0 Probability = 0.8668, Class 1 Probability = 0.1332
# Sample 6: Class 0 Probability = 0.9525, Class 1 Probability = 0.0475
# Sample 7: Class 0 Probability = 0.9297, Class 1 Probability = 0.0703
# Sample 8: Class 0 Probability = 0.1645, Class 1 Probability = 0.8355
# Sample 9: Class 0 Probability = 0.8905, Class 1 Probability = 0.1095
# Sample 10: Class 0 Probability = 0.9116, Class 1 Probability = 0.0884
# Sample 11: Class 0 Probability = 0.9826, Class 1 Probability = 0.0174
# Sample 12: Class 0 Probability = 0.9407, Class 1 Probability = 0.0593
# Sample 13: Class 0 Probability = 0.8659, Class 1 Probability = 0.1341
# Sample 14: Class 0 Probability = 0.9696, Class 1 Probability = 0.0304
# Sample 15: Class 0 Probability = 0.8889, Class 1 Probability = 0.1111
# Sample 16: Class 0 Probability = 0.9040, Class 1 Probability = 0.0960
# Sample 17: Class 0 Probability = 0.9704, Class 1 Probability = 0.0296
# Sample 18: Class 0 Probability = 0.9408, Class 1 Probability = 0.0592
# Sample 19: Class 0 Probability = 0.5186, Class 1 Probability = 0.4814
# Sample 20: Class 0 Probability = 0.9778, Class 1 Probability = 0.0222
# Sample 21: Class 0 Probability = 0.8833, Class 1 Probability = 0.1167
# Sample 22: Class 0 Probability = 0.9127, Class 1 Probability = 0.0873
# Sample 23: Class 0 Probability = 0.8709, Class 1 Probability = 0.1291
# Sample 24: Class 0 Probability = 0.9377, Class 1 Probability = 0.0623
# Sample 25: Class 0 Probability = 0.4575, Class 1 Probability = 0.5425
# Sample 26: Class 0 Probability = 0.9777, Class 1 Probability = 0.0223
# Sample 27: Class 0 Probability = 0.7351, Class 1 Probability = 0.2649
# Sample 28: Class 0 Probability = 0.9347, Class 1 Probability = 0.0653
# Sample 29: Class 0 Probability = 0.9191, Class 1 Probability = 0.0809
# Sample 30: Class 0 Probability = 0.9091, Class 1 Probability = 0.0909
# Sample 31: Class 0 Probability = 0.4855, Class 1 Probability = 0.5145
# Sample 32: Class 0 Probability = 0.9779, Class 1 Probability = 0.0221
# Sample 33: Class 0 Probability = 0.9663, Class 1 Probability = 0.0337
# Sample 34: Class 0 Probability = 0.8142, Class 1 Probability = 0.1858
# Sample 35: Class 0 Probability = 0.9292, Class 1 Probability = 0.0708
# Sample 36: Class 0 Probability = 0.9663, Class 1 Probability = 0.0337
# Sample 37: Class 0 Probability = 0.1336, Class 1 Probability = 0.8664
# Sample 38: Class 0 Probability = 0.9448, Class 1 Probability = 0.0552
# Sample 39: Class 0 Probability = 0.8760, Class 1 Probability = 0.1240
# Sample 40: Class 0 Probability = 0.7378, Class 1 Probability = 0.2622
# Sample 41: Class 0 Probability = 0.9566, Class 1 Probability = 0.0434
# Sample 42: Class 0 Probability = 0.8873, Class 1 Probability = 0.1127
# Sample 43: Class 0 Probability = 0.9220, Class 1 Probability = 0.0780
# Sample 44: Class 0 Probability = 0.9864, Class 1 Probability = 0.0136
# Sample 45: Class 0 Probability = 0.9376, Class 1 Probability = 0.0624
# Sample 46: Class 0 Probability = 0.9666, Class 1 Probability = 0.0334
# Sample 47: Class 0 Probability = 0.8910, Class 1 Probability = 0.1090
# Sample 48: Class 0 Probability = 0.9314, Class 1 Probability = 0.0686
# Sample 49: Class 0 Probability = 0.8948, Class 1 Probability = 0.1052
# Sample 50: Class 0 Probability = 0.8841, Class 1 Probability = 0.1159
# Sample 51: Class 0 Probability = 0.8525, Class 1 Probability = 0.1475
# Sample 52: Class 0 Probability = 0.6859, Class 1 Probability = 0.3141
# Sample 53: Class 0 Probability = 0.9433, Class 1 Probability = 0.0567
# Sample 54: Class 0 Probability = 0.8686, Class 1 Probability = 0.1314
# Sample 55: Class 0 Probability = 0.9628, Class 1 Probability = 0.0372
# Sample 56: Class 0 Probability = 0.8980, Class 1 Probability = 0.1020
# Sample 57: Class 0 Probability = 0.9379, Class 1 Probability = 0.0621
# Sample 58: Class 0 Probability = 0.9746, Class 1 Probability = 0.0254
# Sample 59: Class 0 Probability = 0.8978, Class 1 Probability = 0.1022
# Sample 60: Class 0 Probability = 0.9155, Class 1 Probability = 0.0845
# Sample 61: Class 0 Probability = 0.9240, Class 1 Probability = 0.0760
# Sample 62: Class 0 Probability = 0.8877, Class 1 Probability = 0.1123
# Sample 63: Class 0 Probability = 0.2667, Class 1 Probability = 0.7333
# Sample 64: Class 0 Probability = 0.9785, Class 1 Probability = 0.0215
# Sample 65: Class 0 Probability = 0.9645, Class 1 Probability = 0.0355
# Sample 66: Class 0 Probability = 0.8750, Class 1 Probability = 0.1250
# Sample 67: Class 0 Probability = 0.9737, Class 1 Probability = 0.0263
# Sample 68: Class 0 Probability = 0.7303, Class 1 Probability = 0.2697
# Sample 69: Class 0 Probability = 0.8037, Class 1 Probability = 0.1963
# Sample 70: Class 0 Probability = 0.8678, Class 1 Probability = 0.1322
# Sample 71: Class 0 Probability = 0.8104, Class 1 Probability = 0.1896
# Sample 72: Class 0 Probability = 0.9581, Class 1 Probability = 0.0419
# Sample 73: Class 0 Probability = 0.9787, Class 1 Probability = 0.0213
# Sample 74: Class 0 Probability = 0.9387, Class 1 Probability = 0.0613
# Sample 75: Class 0 Probability = 0.8986, Class 1 Probability = 0.1014
# Sample 76: Class 0 Probability = 0.7468, Class 1 Probability = 0.2532
# Sample 77: Class 0 Probability = 0.5215, Class 1 Probability = 0.4785
# Sample 78: Class 0 Probability = 0.8607, Class 1 Probability = 0.1393
# Sample 79: Class 0 Probability = 0.9282, Class 1 Probability = 0.0718
# Sample 80: Class 0 Probability = 0.8788, Class 1 Probability = 0.1212
# Sample 81: Class 0 Probability = 0.9303, Class 1 Probability = 0.0697
# Sample 82: Class 0 Probability = 0.8873, Class 1 Probability = 0.1127
# Sample 83: Class 0 Probability = 0.9606, Class 1 Probability = 0.0394
# Sample 84: Class 0 Probability = 0.9032, Class 1 Probability = 0.0968
# Sample 85: Class 0 Probability = 0.9555, Class 1 Probability = 0.0445
# Sample 86: Class 0 Probability = 0.9758, Class 1 Probability = 0.0242
# Sample 87: Class 0 Probability = 0.8730, Class 1 Probability = 0.1270
# Sample 88: Class 0 Probability = 0.9004, Class 1 Probability = 0.0996
# Sample 89: Class 0 Probability = 0.9697, Class 1 Probability = 0.0303
# Sample 90: Class 0 Probability = 0.9934, Class 1 Probability = 0.0066
# Sample 91: Class 0 Probability = 0.9731, Class 1 Probability = 0.0269
# Sample 92: Class 0 Probability = 0.8664, Class 1 Probability = 0.1336
# Sample 93: Class 0 Probability = 0.1600, Class 1 Probability = 0.8400
# Sample 94: Class 0 Probability = 0.9007, Class 1 Probability = 0.0993
# Sample 95: Class 0 Probability = 0.9355, Class 1 Probability = 0.0645
# Sample 96: Class 0 Probability = 0.9244, Class 1 Probability = 0.0756
# Sample 97: Class 0 Probability = 0.4650, Class 1 Probability = 0.5350
# Sample 98: Class 0 Probability = 0.9392, Class 1 Probability = 0.0608
# Sample 99: Class 0 Probability = 0.8910, Class 1 Probability = 0.1090
# Sample 100: Class 0 Probability = 0.7621, Class 1 Probability = 0.2379
# Sample 101: Class 0 Probability = 0.8763, Class 1 Probability = 0.1237
# Sample 102: Class 0 Probability = 0.9188, Class 1 Probability = 0.0812
# Sample 103: Class 0 Probability = 0.9518, Class 1 Probability = 0.0482
# Sample 104: Class 0 Probability = 0.9503, Class 1 Probability = 0.0497
# Sample 105: Class 0 Probability = 0.9659, Class 1 Probability = 0.0341
# Sample 106: Class 0 Probability = 0.8994, Class 1 Probability = 0.1006
# Sample 107: Class 0 Probability = 0.8773, Class 1 Probability = 0.1227
# Sample 108: Class 0 Probability = 0.9278, Class 1 Probability = 0.0722
# Sample 109: Class 0 Probability = 0.9087, Class 1 Probability = 0.0913
# Sample 110: Class 0 Probability = 0.9185, Class 1 Probability = 0.0815
# Sample 111: Class 0 Probability = 0.8298, Class 1 Probability = 0.1702
# Sample 112: Class 0 Probability = 0.9307, Class 1 Probability = 0.0693
# Sample 113: Class 0 Probability = 0.9701, Class 1 Probability = 0.0299
# Sample 114: Class 0 Probability = 0.9538, Class 1 Probability = 0.0462
# Sample 115: Class 0 Probability = 0.9439, Class 1 Probability = 0.0561
# Sample 116: Class 0 Probability = 0.9111, Class 1 Probability = 0.0889
# Sample 117: Class 0 Probability = 0.9870, Class 1 Probability = 0.0130
# Sample 118: Class 0 Probability = 0.9641, Class 1 Probability = 0.0359
# Sample 119: Class 0 Probability = 0.9001, Class 1 Probability = 0.0999
# Sample 120: Class 0 Probability = 0.7789, Class 1 Probability = 0.2211
# Sample 121: Class 0 Probability = 0.8806, Class 1 Probability = 0.1194
# Sample 122: Class 0 Probability = 0.7283, Class 1 Probability = 0.2717
# Sample 123: Class 0 Probability = 0.9280, Class 1 Probability = 0.0720
# Sample 124: Class 0 Probability = 0.9050, Class 1 Probability = 0.0950
# Sample 125: Class 0 Probability = 0.9926, Class 1 Probability = 0.0074
# Sample 126: Class 0 Probability = 0.9656, Class 1 Probability = 0.0344
# Sample 127: Class 0 Probability = 0.9442, Class 1 Probability = 0.0558
# Sample 128: Class 0 Probability = 0.9241, Class 1 Probability = 0.0759
# Sample 129: Class 0 Probability = 0.8913, Class 1 Probability = 0.1087
# Sample 130: Class 0 Probability = 0.8961, Class 1 Probability = 0.1039
# Sample 131: Class 0 Probability = 0.9335, Class 1 Probability = 0.0665
# Sample 132: Class 0 Probability = 0.9779, Class 1 Probability = 0.0221
# Sample 133: Class 0 Probability = 0.9568, Class 1 Probability = 0.0432
# Sample 134: Class 0 Probability = 0.9645, Class 1 Probability = 0.0355
# Sample 135: Class 0 Probability = 0.9136, Class 1 Probability = 0.0864
# Sample 136: Class 0 Probability = 0.8743, Class 1 Probability = 0.1257
# Sample 137: Class 0 Probability = 0.9299, Class 1 Probability = 0.0701
# Sample 138: Class 0 Probability = 0.7780, Class 1 Probability = 0.2220
# Sample 139: Class 0 Probability = 0.6596, Class 1 Probability = 0.3404
# Sample 140: Class 0 Probability = 0.9792, Class 1 Probability = 0.0208
# Sample 141: Class 0 Probability = 0.4779, Class 1 Probability = 0.5221
# Sample 142: Class 0 Probability = 0.9130, Class 1 Probability = 0.0870
# Sample 143: Class 0 Probability = 0.9139, Class 1 Probability = 0.0861
# Sample 144: Class 0 Probability = 0.9660, Class 1 Probability = 0.0340
# Sample 145: Class 0 Probability = 0.9282, Class 1 Probability = 0.0718
# Sample 146: Class 0 Probability = 0.6279, Class 1 Probability = 0.3721
# Sample 147: Class 0 Probability = 0.9218, Class 1 Probability = 0.0782
# Sample 148: Class 0 Probability = 0.7956, Class 1 Probability = 0.2044
# Sample 149: Class 0 Probability = 0.9436, Class 1 Probability = 0.0564
# Sample 150: Class 0 Probability = 0.8657, Class 1 Probability = 0.1343
# Sample 151: Class 0 Probability = 0.9128, Class 1 Probability = 0.0872
# Sample 152: Class 0 Probability = 0.8597, Class 1 Probability = 0.1403
# Sample 153: Class 0 Probability = 0.9181, Class 1 Probability = 0.0819
# Sample 154: Class 0 Probability = 0.8542, Class 1 Probability = 0.1458
# Sample 155: Class 0 Probability = 0.9027, Class 1 Probability = 0.0973
# Sample 156: Class 0 Probability = 0.8852, Class 1 Probability = 0.1148
# Sample 157: Class 0 Probability = 0.8485, Class 1 Probability = 0.1515
# Sample 158: Class 0 Probability = 0.9471, Class 1 Probability = 0.0529
# Sample 159: Class 0 Probability = 0.2969, Class 1 Probability = 0.7031
# Sample 160: Class 0 Probability = 0.9682, Class 1 Probability = 0.0318
# Sample 161: Class 0 Probability = 0.7630, Class 1 Probability = 0.2370
# Sample 162: Class 0 Probability = 0.8677, Class 1 Probability = 0.1323
# Sample 163: Class 0 Probability = 0.8839, Class 1 Probability = 0.1161
# Sample 164: Class 0 Probability = 0.9309, Class 1 Probability = 0.0691
# Sample 165: Class 0 Probability = 0.9110, Class 1 Probability = 0.0890
# Sample 166: Class 0 Probability = 0.9412, Class 1 Probability = 0.0588
# Sample 167: Class 0 Probability = 0.8762, Class 1 Probability = 0.1238
# Sample 168: Class 0 Probability = 0.9728, Class 1 Probability = 0.0272
# Sample 169: Class 0 Probability = 0.9204, Class 1 Probability = 0.0796
# Sample 170: Class 0 Probability = 0.8524, Class 1 Probability = 0.1476
# Sample 171: Class 0 Probability = 0.8992, Class 1 Probability = 0.1008
# Sample 172: Class 0 Probability = 0.9808, Class 1 Probability = 0.0192
# Sample 173: Class 0 Probability = 0.9220, Class 1 Probability = 0.0780
# Sample 174: Class 0 Probability = 0.9794, Class 1 Probability = 0.0206
# Sample 175: Class 0 Probability = 0.7840, Class 1 Probability = 0.2160
# Sample 176: Class 0 Probability = 0.8595, Class 1 Probability = 0.1405
# Sample 177: Class 0 Probability = 0.9552, Class 1 Probability = 0.0448
# Sample 178: Class 0 Probability = 0.8472, Class 1 Probability = 0.1528
# Sample 179: Class 0 Probability = 0.8878, Class 1 Probability = 0.1122
# Sample 180: Class 0 Probability = 0.9591, Class 1 Probability = 0.0409
# Sample 181: Class 0 Probability = 0.9737, Class 1 Probability = 0.0263
# Sample 182: Class 0 Probability = 0.9710, Class 1 Probability = 0.0290
# Sample 183: Class 0 Probability = 0.8809, Class 1 Probability = 0.1191
# Sample 184: Class 0 Probability = 0.9152, Class 1 Probability = 0.0848
# Sample 185: Class 0 Probability = 0.9568, Class 1 Probability = 0.0432
# Sample 186: Class 0 Probability = 0.9786, Class 1 Probability = 0.0214
# Sample 187: Class 0 Probability = 0.9069, Class 1 Probability = 0.0931
# Sample 188: Class 0 Probability = 0.2216, Class 1 Probability = 0.7784
# Sample 189: Class 0 Probability = 0.6261, Class 1 Probability = 0.3739
# Sample 190: Class 0 Probability = 0.9691, Class 1 Probability = 0.0309
# Sample 191: Class 0 Probability = 0.8981, Class 1 Probability = 0.1019
# Sample 192: Class 0 Probability = 0.9799, Class 1 Probability = 0.0201
# Sample 193: Class 0 Probability = 0.9808, Class 1 Probability = 0.0192
# Sample 194: Class 0 Probability = 0.9630, Class 1 Probability = 0.0370
# Sample 195: Class 0 Probability = 0.9103, Class 1 Probability = 0.0897
# Sample 196: Class 0 Probability = 0.9401, Class 1 Probability = 0.0599
# Sample 197: Class 0 Probability = 0.9806, Class 1 Probability = 0.0194
# Sample 198: Class 0 Probability = 0.9267, Class 1 Probability = 0.0733
# Sample 199: Class 0 Probability = 0.9828, Class 1 Probability = 0.0172
# Sample 200: Class 0 Probability = 0.9751, Class 1 Probability = 0.0249
# Sample 201: Class 0 Probability = 0.9666, Class 1 Probability = 0.0334
# Sample 202: Class 0 Probability = 0.8938, Class 1 Probability = 0.1062
# Sample 203: Class 0 Probability = 0.9229, Class 1 Probability = 0.0771
# Sample 204: Class 0 Probability = 0.9219, Class 1 Probability = 0.0781
# Sample 205: Class 0 Probability = 0.8658, Class 1 Probability = 0.1342
# Sample 206: Class 0 Probability = 0.9759, Class 1 Probability = 0.0241
# Sample 207: Class 0 Probability = 0.9094, Class 1 Probability = 0.0906
# Sample 208: Class 0 Probability = 0.9140, Class 1 Probability = 0.0860
# Sample 209: Class 0 Probability = 0.9813, Class 1 Probability = 0.0187
# Sample 210: Class 0 Probability = 0.7514, Class 1 Probability = 0.2486
# Sample 211: Class 0 Probability = 0.9788, Class 1 Probability = 0.0212
# Sample 212: Class 0 Probability = 0.9793, Class 1 Probability = 0.0207
# Sample 213: Class 0 Probability = 0.8493, Class 1 Probability = 0.1507
# Sample 214: Class 0 Probability = 0.9737, Class 1 Probability = 0.0263
# Sample 215: Class 0 Probability = 0.9824, Class 1 Probability = 0.0176
# Sample 216: Class 0 Probability = 0.8314, Class 1 Probability = 0.1686
# Sample 217: Class 0 Probability = 0.8835, Class 1 Probability = 0.1165
# Sample 218: Class 0 Probability = 0.9649, Class 1 Probability = 0.0351
# Sample 219: Class 0 Probability = 0.8042, Class 1 Probability = 0.1958
# Sample 220: Class 0 Probability = 0.9141, Class 1 Probability = 0.0859
# Sample 221: Class 0 Probability = 0.9687, Class 1 Probability = 0.0313
# Sample 222: Class 0 Probability = 0.9846, Class 1 Probability = 0.0154
# Sample 223: Class 0 Probability = 0.9324, Class 1 Probability = 0.0676
# Sample 224: Class 0 Probability = 0.9697, Class 1 Probability = 0.0303
# Sample 225: Class 0 Probability = 0.9801, Class 1 Probability = 0.0199
# Sample 226: Class 0 Probability = 0.9161, Class 1 Probability = 0.0839
# Sample 227: Class 0 Probability = 0.8710, Class 1 Probability = 0.1290
# Sample 228: Class 0 Probability = 0.8760, Class 1 Probability = 0.1240
# Sample 229: Class 0 Probability = 0.9476, Class 1 Probability = 0.0524
# Sample 230: Class 0 Probability = 0.9164, Class 1 Probability = 0.0836
# Sample 231: Class 0 Probability = 0.8803, Class 1 Probability = 0.1197
# Sample 232: Class 0 Probability = 0.8485, Class 1 Probability = 0.1515
# Sample 233: Class 0 Probability = 0.9515, Class 1 Probability = 0.0485
# Sample 234: Class 0 Probability = 0.7738, Class 1 Probability = 0.2262
# Sample 235: Class 0 Probability = 0.8919, Class 1 Probability = 0.1081
# Sample 236: Class 0 Probability = 0.9590, Class 1 Probability = 0.0410
# Sample 237: Class 0 Probability = 0.9576, Class 1 Probability = 0.0424
# Sample 238: Class 0 Probability = 0.8917, Class 1 Probability = 0.1083
# Sample 239: Class 0 Probability = 0.9165, Class 1 Probability = 0.0835
# Sample 240: Class 0 Probability = 0.9559, Class 1 Probability = 0.0441
# Sample 241: Class 0 Probability = 0.9648, Class 1 Probability = 0.0352
# Sample 242: Class 0 Probability = 0.9453, Class 1 Probability = 0.0547
# Sample 243: Class 0 Probability = 0.9370, Class 1 Probability = 0.0630
# Sample 244: Class 0 Probability = 0.8137, Class 1 Probability = 0.1863
# Sample 245: Class 0 Probability = 0.9726, Class 1 Probability = 0.0274
# Sample 246: Class 0 Probability = 0.8613, Class 1 Probability = 0.1387
# Sample 247: Class 0 Probability = 0.9157, Class 1 Probability = 0.0843
# Sample 248: Class 0 Probability = 0.9349, Class 1 Probability = 0.0651
# Sample 249: Class 0 Probability = 0.8129, Class 1 Probability = 0.1871
# Sample 250: Class 0 Probability = 0.9447, Class 1 Probability = 0.0553
# Sample 251: Class 0 Probability = 0.8255, Class 1 Probability = 0.1745
# Sample 252: Class 0 Probability = 0.8133, Class 1 Probability = 0.1867
# Sample 253: Class 0 Probability = 0.9276, Class 1 Probability = 0.0724
# Sample 254: Class 0 Probability = 0.9745, Class 1 Probability = 0.0255
# Sample 255: Class 0 Probability = 0.9070, Class 1 Probability = 0.0930
# Sample 256: Class 0 Probability = 0.9598, Class 1 Probability = 0.0402
# Sample 257: Class 0 Probability = 0.9149, Class 1 Probability = 0.0851
# Sample 258: Class 0 Probability = 0.9248, Class 1 Probability = 0.0752
# Sample 259: Class 0 Probability = 0.9603, Class 1 Probability = 0.0397
# Sample 260: Class 0 Probability = 0.9626, Class 1 Probability = 0.0374
# Sample 261: Class 0 Probability = 0.9768, Class 1 Probability = 0.0232
# Sample 262: Class 0 Probability = 0.8742, Class 1 Probability = 0.1258
# Sample 263: Class 0 Probability = 0.8729, Class 1 Probability = 0.1271
# Sample 264: Class 0 Probability = 0.1050, Class 1 Probability = 0.8950
# Sample 265: Class 0 Probability = 0.7240, Class 1 Probability = 0.2760
# Sample 266: Class 0 Probability = 0.9488, Class 1 Probability = 0.0512
# Sample 267: Class 0 Probability = 0.9057, Class 1 Probability = 0.0943
# Sample 268: Class 0 Probability = 0.8690, Class 1 Probability = 0.1310
# Sample 269: Class 0 Probability = 0.9297, Class 1 Probability = 0.0703
# Sample 270: Class 0 Probability = 0.8865, Class 1 Probability = 0.1135
# Sample 271: Class 0 Probability = 0.8983, Class 1 Probability = 0.1017
# Sample 272: Class 0 Probability = 0.8721, Class 1 Probability = 0.1279
# Sample 273: Class 0 Probability = 0.9343, Class 1 Probability = 0.0657
# Sample 274: Class 0 Probability = 0.9669, Class 1 Probability = 0.0331
# Sample 275: Class 0 Probability = 0.9703, Class 1 Probability = 0.0297
# Sample 276: Class 0 Probability = 0.9024, Class 1 Probability = 0.0976
# Sample 277: Class 0 Probability = 0.8113, Class 1 Probability = 0.1887
# Sample 278: Class 0 Probability = 0.4788, Class 1 Probability = 0.5212
# Sample 279: Class 0 Probability = 0.9201, Class 1 Probability = 0.0799
# Sample 280: Class 0 Probability = 0.8952, Class 1 Probability = 0.1048
# Sample 281: Class 0 Probability = 0.8745, Class 1 Probability = 0.1255
# Sample 282: Class 0 Probability = 0.9387, Class 1 Probability = 0.0613
# Sample 283: Class 0 Probability = 0.9268, Class 1 Probability = 0.0732
# Sample 284: Class 0 Probability = 0.5933, Class 1 Probability = 0.4067
# Sample 285: Class 0 Probability = 0.9116, Class 1 Probability = 0.0884
# Sample 286: Class 0 Probability = 0.9769, Class 1 Probability = 0.0231
# Sample 287: Class 0 Probability = 0.9047, Class 1 Probability = 0.0953
# Sample 288: Class 0 Probability = 0.8214, Class 1 Probability = 0.1786
# Sample 289: Class 0 Probability = 0.9752, Class 1 Probability = 0.0248
# Sample 290: Class 0 Probability = 0.9856, Class 1 Probability = 0.0144
# Sample 291: Class 0 Probability = 0.9494, Class 1 Probability = 0.0506
# Sample 292: Class 0 Probability = 0.9245, Class 1 Probability = 0.0755
# Sample 293: Class 0 Probability = 0.9494, Class 1 Probability = 0.0506
# Sample 294: Class 0 Probability = 0.9781, Class 1 Probability = 0.0219
# Sample 295: Class 0 Probability = 0.8895, Class 1 Probability = 0.1105
# Sample 296: Class 0 Probability = 0.8945, Class 1 Probability = 0.1055
# Sample 297: Class 0 Probability = 0.9651, Class 1 Probability = 0.0349
# Sample 298: Class 0 Probability = 0.8708, Class 1 Probability = 0.1292
# Sample 299: Class 0 Probability = 0.9760, Class 1 Probability = 0.0240
# Sample 300: Class 0 Probability = 0.9350, Class 1 Probability = 0.0650
# Sample 301: Class 0 Probability = 0.9307, Class 1 Probability = 0.0693
# Sample 302: Class 0 Probability = 0.8630, Class 1 Probability = 0.1370
# Sample 303: Class 0 Probability = 0.9146, Class 1 Probability = 0.0854
# Sample 304: Class 0 Probability = 0.5750, Class 1 Probability = 0.4250
# Sample 305: Class 0 Probability = 0.7807, Class 1 Probability = 0.2193
# Sample 306: Class 0 Probability = 0.9406, Class 1 Probability = 0.0594
# Sample 307: Class 0 Probability = 0.9550, Class 1 Probability = 0.0450
# Sample 308: Class 0 Probability = 0.7663, Class 1 Probability = 0.2337
# Sample 309: Class 0 Probability = 0.9393, Class 1 Probability = 0.0607
# Sample 310: Class 0 Probability = 0.9100, Class 1 Probability = 0.0900
# Sample 311: Class 0 Probability = 0.9521, Class 1 Probability = 0.0479
# Sample 312: Class 0 Probability = 0.9757, Class 1 Probability = 0.0243
# Sample 313: Class 0 Probability = 0.9598, Class 1 Probability = 0.0402
# Sample 314: Class 0 Probability = 0.9192, Class 1 Probability = 0.0808
# Sample 315: Class 0 Probability = 0.9530, Class 1 Probability = 0.0470
# Sample 316: Class 0 Probability = 0.9666, Class 1 Probability = 0.0334
# Sample 317: Class 0 Probability = 0.9693, Class 1 Probability = 0.0307
# Sample 318: Class 0 Probability = 0.9100, Class 1 Probability = 0.0900
# Sample 319: Class 0 Probability = 0.9695, Class 1 Probability = 0.0305
# Sample 320: Class 0 Probability = 0.9416, Class 1 Probability = 0.0584
# Sample 321: Class 0 Probability = 0.8500, Class 1 Probability = 0.1500
# Sample 322: Class 0 Probability = 0.9784, Class 1 Probability = 0.0216
# Sample 323: Class 0 Probability = 0.9207, Class 1 Probability = 0.0793
# Sample 324: Class 0 Probability = 0.9641, Class 1 Probability = 0.0359
# Sample 325: Class 0 Probability = 0.8672, Class 1 Probability = 0.1328
# Sample 326: Class 0 Probability = 0.9062, Class 1 Probability = 0.0938
# Sample 327: Class 0 Probability = 0.9361, Class 1 Probability = 0.0639
# Sample 328: Class 0 Probability = 0.8963, Class 1 Probability = 0.1037
# Sample 329: Class 0 Probability = 0.9376, Class 1 Probability = 0.0624
# Sample 330: Class 0 Probability = 0.8091, Class 1 Probability = 0.1909
# Sample 331: Class 0 Probability = 0.9694, Class 1 Probability = 0.0306
# Sample 332: Class 0 Probability = 0.9015, Class 1 Probability = 0.0985
# Sample 333: Class 0 Probability = 0.9754, Class 1 Probability = 0.0246
# Sample 334: Class 0 Probability = 0.8926, Class 1 Probability = 0.1074
# Sample 335: Class 0 Probability = 0.9581, Class 1 Probability = 0.0419
# Sample 336: Class 0 Probability = 0.9265, Class 1 Probability = 0.0735
# Sample 337: Class 0 Probability = 0.9523, Class 1 Probability = 0.0477
# Sample 338: Class 0 Probability = 0.9649, Class 1 Probability = 0.0351
# Sample 339: Class 0 Probability = 0.9846, Class 1 Probability = 0.0154
# Sample 340: Class 0 Probability = 0.9720, Class 1 Probability = 0.0280
# Sample 341: Class 0 Probability = 0.9768, Class 1 Probability = 0.0232
# Sample 342: Class 0 Probability = 0.9320, Class 1 Probability = 0.0680
# Sample 343: Class 0 Probability = 0.8358, Class 1 Probability = 0.1642
# Sample 344: Class 0 Probability = 0.9370, Class 1 Probability = 0.0630
# Sample 345: Class 0 Probability = 0.7878, Class 1 Probability = 0.2122
# Sample 346: Class 0 Probability = 0.9363, Class 1 Probability = 0.0637
# Sample 347: Class 0 Probability = 0.9463, Class 1 Probability = 0.0537
# Sample 348: Class 0 Probability = 0.9784, Class 1 Probability = 0.0216
# Sample 349: Class 0 Probability = 0.4065, Class 1 Probability = 0.5935
# Sample 350: Class 0 Probability = 0.9357, Class 1 Probability = 0.0643
# Sample 351: Class 0 Probability = 0.8969, Class 1 Probability = 0.1031
# Sample 352: Class 0 Probability = 0.9851, Class 1 Probability = 0.0149
# Sample 353: Class 0 Probability = 0.3801, Class 1 Probability = 0.6199
# Sample 354: Class 0 Probability = 0.9098, Class 1 Probability = 0.0902
# Sample 355: Class 0 Probability = 0.9379, Class 1 Probability = 0.0621
# Sample 356: Class 0 Probability = 0.9771, Class 1 Probability = 0.0229
# Sample 357: Class 0 Probability = 0.8977, Class 1 Probability = 0.1023
# Sample 358: Class 0 Probability = 0.9777, Class 1 Probability = 0.0223
# Sample 359: Class 0 Probability = 0.9447, Class 1 Probability = 0.0553
# Sample 360: Class 0 Probability = 0.8872, Class 1 Probability = 0.1128
# Sample 361: Class 0 Probability = 0.9315, Class 1 Probability = 0.0685
# Sample 362: Class 0 Probability = 0.8754, Class 1 Probability = 0.1246
# Sample 363: Class 0 Probability = 0.9021, Class 1 Probability = 0.0979
# Sample 364: Class 0 Probability = 0.9373, Class 1 Probability = 0.0627
# Sample 365: Class 0 Probability = 0.9769, Class 1 Probability = 0.0231
# Sample 366: Class 0 Probability = 0.9110, Class 1 Probability = 0.0890
# Sample 367: Class 0 Probability = 0.9322, Class 1 Probability = 0.0678
# Sample 368: Class 0 Probability = 0.9826, Class 1 Probability = 0.0174
# Sample 369: Class 0 Probability = 0.9394, Class 1 Probability = 0.0606
# Sample 370: Class 0 Probability = 0.7474, Class 1 Probability = 0.2526
# Sample 371: Class 0 Probability = 0.9459, Class 1 Probability = 0.0541
# Sample 372: Class 0 Probability = 0.8896, Class 1 Probability = 0.1104
# Sample 373: Class 0 Probability = 0.8789, Class 1 Probability = 0.1211
# Sample 374: Class 0 Probability = 0.9753, Class 1 Probability = 0.0247
# Sample 375: Class 0 Probability = 0.9423, Class 1 Probability = 0.0577
# Sample 376: Class 0 Probability = 0.8425, Class 1 Probability = 0.1575
# Sample 377: Class 0 Probability = 0.4024, Class 1 Probability = 0.5976
# Sample 378: Class 0 Probability = 0.8774, Class 1 Probability = 0.1226
# Sample 379: Class 0 Probability = 0.9045, Class 1 Probability = 0.0955
# Sample 380: Class 0 Probability = 0.9595, Class 1 Probability = 0.0405
# Sample 381: Class 0 Probability = 0.9187, Class 1 Probability = 0.0813
# Sample 382: Class 0 Probability = 0.8891, Class 1 Probability = 0.1109
# Sample 383: Class 0 Probability = 0.8434, Class 1 Probability = 0.1566
# Sample 384: Class 0 Probability = 0.9759, Class 1 Probability = 0.0241
# Sample 385: Class 0 Probability = 0.8719, Class 1 Probability = 0.1281
# Sample 386: Class 0 Probability = 0.8828, Class 1 Probability = 0.1172
# Sample 387: Class 0 Probability = 0.9180, Class 1 Probability = 0.0820
# Sample 388: Class 0 Probability = 0.9584, Class 1 Probability = 0.0416
# Sample 389: Class 0 Probability = 0.8961, Class 1 Probability = 0.1039
# Sample 390: Class 0 Probability = 0.8556, Class 1 Probability = 0.1444
# Sample 391: Class 0 Probability = 0.9686, Class 1 Probability = 0.0314
# Sample 392: Class 0 Probability = 0.8822, Class 1 Probability = 0.1178
# Sample 393: Class 0 Probability = 0.9311, Class 1 Probability = 0.0689
# Sample 394: Class 0 Probability = 0.9693, Class 1 Probability = 0.0307
# Sample 395: Class 0 Probability = 0.9756, Class 1 Probability = 0.0244
# Sample 396: Class 0 Probability = 0.8864, Class 1 Probability = 0.1136
# Sample 397: Class 0 Probability = 0.8581, Class 1 Probability = 0.1419
# Sample 398: Class 0 Probability = 0.8875, Class 1 Probability = 0.1125
# Sample 399: Class 0 Probability = 0.5220, Class 1 Probability = 0.4780
# Sample 400: Class 0 Probability = 0.8779, Class 1 Probability = 0.1221
# Sample 401: Class 0 Probability = 0.8825, Class 1 Probability = 0.1175
# Sample 402: Class 0 Probability = 0.8449, Class 1 Probability = 0.1551
# Sample 403: Class 0 Probability = 0.8302, Class 1 Probability = 0.1698
# Sample 404: Class 0 Probability = 0.8787, Class 1 Probability = 0.1213
# Sample 405: Class 0 Probability = 0.8444, Class 1 Probability = 0.1556
# Sample 406: Class 0 Probability = 0.9751, Class 1 Probability = 0.0249
# Sample 407: Class 0 Probability = 0.9699, Class 1 Probability = 0.0301
# Sample 408: Class 0 Probability = 0.9787, Class 1 Probability = 0.0213
# Sample 409: Class 0 Probability = 0.9078, Class 1 Probability = 0.0922
# Sample 410: Class 0 Probability = 0.9279, Class 1 Probability = 0.0721
# Sample 411: Class 0 Probability = 0.8070, Class 1 Probability = 0.1930
# Sample 412: Class 0 Probability = 0.8759, Class 1 Probability = 0.1241
# Sample 413: Class 0 Probability = 0.9786, Class 1 Probability = 0.0214
# Sample 414: Class 0 Probability = 0.3020, Class 1 Probability = 0.6980
# Sample 415: Class 0 Probability = 0.9663, Class 1 Probability = 0.0337
# Sample 416: Class 0 Probability = 0.9166, Class 1 Probability = 0.0834
# Sample 417: Class 0 Probability = 0.9369, Class 1 Probability = 0.0631
# Sample 418: Class 0 Probability = 0.5858, Class 1 Probability = 0.4142
# Sample 419: Class 0 Probability = 0.9593, Class 1 Probability = 0.0407
# Sample 420: Class 0 Probability = 0.9543, Class 1 Probability = 0.0457
# Sample 421: Class 0 Probability = 0.9394, Class 1 Probability = 0.0606
# Sample 422: Class 0 Probability = 0.8988, Class 1 Probability = 0.1012
# Sample 423: Class 0 Probability = 0.9643, Class 1 Probability = 0.0357
# Sample 424: Class 0 Probability = 0.9224, Class 1 Probability = 0.0776
# Sample 425: Class 0 Probability = 0.8368, Class 1 Probability = 0.1632
# Sample 426: Class 0 Probability = 0.9549, Class 1 Probability = 0.0451
# Sample 427: Class 0 Probability = 0.9723, Class 1 Probability = 0.0277
# Sample 428: Class 0 Probability = 0.9091, Class 1 Probability = 0.0909
# Sample 429: Class 0 Probability = 0.9782, Class 1 Probability = 0.0218
# Sample 430: Class 0 Probability = 0.9190, Class 1 Probability = 0.0810
# Sample 431: Class 0 Probability = 0.8786, Class 1 Probability = 0.1214
# Sample 432: Class 0 Probability = 0.9250, Class 1 Probability = 0.0750
# Sample 433: Class 0 Probability = 0.9767, Class 1 Probability = 0.0233
# Sample 434: Class 0 Probability = 0.9660, Class 1 Probability = 0.0340
# Sample 435: Class 0 Probability = 0.9962, Class 1 Probability = 0.0038
# Sample 436: Class 0 Probability = 0.9427, Class 1 Probability = 0.0573
# Sample 437: Class 0 Probability = 0.9268, Class 1 Probability = 0.0732
# Sample 438: Class 0 Probability = 0.9699, Class 1 Probability = 0.0301
# Sample 439: Class 0 Probability = 0.8500, Class 1 Probability = 0.1500
# Sample 440: Class 0 Probability = 0.9804, Class 1 Probability = 0.0196
# Sample 441: Class 0 Probability = 0.8250, Class 1 Probability = 0.1750
# Sample 442: Class 0 Probability = 0.9255, Class 1 Probability = 0.0745
# Sample 443: Class 0 Probability = 0.9440, Class 1 Probability = 0.0560
# Sample 444: Class 0 Probability = 0.9541, Class 1 Probability = 0.0459
# Sample 445: Class 0 Probability = 0.8751, Class 1 Probability = 0.1249
# Sample 446: Class 0 Probability = 0.7903, Class 1 Probability = 0.2097
# Sample 447: Class 0 Probability = 0.9232, Class 1 Probability = 0.0768
# Sample 448: Class 0 Probability = 0.8795, Class 1 Probability = 0.1205
# Sample 449: Class 0 Probability = 0.8767, Class 1 Probability = 0.1233
# Sample 450: Class 0 Probability = 0.9637, Class 1 Probability = 0.0363
# Sample 451: Class 0 Probability = 0.9334, Class 1 Probability = 0.0666
# Sample 452: Class 0 Probability = 0.8548, Class 1 Probability = 0.1452
# Sample 453: Class 0 Probability = 0.9290, Class 1 Probability = 0.0710
# Sample 454: Class 0 Probability = 0.9202, Class 1 Probability = 0.0798
# Sample 455: Class 0 Probability = 0.9212, Class 1 Probability = 0.0788
# Sample 456: Class 0 Probability = 0.9391, Class 1 Probability = 0.0609
# Sample 457: Class 0 Probability = 0.8982, Class 1 Probability = 0.1018
# Sample 458: Class 0 Probability = 0.8813, Class 1 Probability = 0.1187
# Sample 459: Class 0 Probability = 0.6533, Class 1 Probability = 0.3467
# Sample 460: Class 0 Probability = 0.9315, Class 1 Probability = 0.0685
# Sample 461: Class 0 Probability = 0.8546, Class 1 Probability = 0.1454
# Sample 462: Class 0 Probability = 0.9260, Class 1 Probability = 0.0740
# Sample 463: Class 0 Probability = 0.9379, Class 1 Probability = 0.0621
# Sample 464: Class 0 Probability = 0.8867, Class 1 Probability = 0.1133
# Sample 465: Class 0 Probability = 0.9333, Class 1 Probability = 0.0667
# Sample 466: Class 0 Probability = 0.7097, Class 1 Probability = 0.2903
# Sample 467: Class 0 Probability = 0.9533, Class 1 Probability = 0.0467
# Sample 468: Class 0 Probability = 0.8561, Class 1 Probability = 0.1439
# Sample 469: Class 0 Probability = 0.8826, Class 1 Probability = 0.1174
# Sample 470: Class 0 Probability = 0.8476, Class 1 Probability = 0.1524
# Sample 471: Class 0 Probability = 0.9449, Class 1 Probability = 0.0551
# Sample 472: Class 0 Probability = 0.8187, Class 1 Probability = 0.1813
# Sample 473: Class 0 Probability = 0.9065, Class 1 Probability = 0.0935
# Sample 474: Class 0 Probability = 0.9476, Class 1 Probability = 0.0524
# Sample 475: Class 0 Probability = 0.9777, Class 1 Probability = 0.0223
# Sample 476: Class 0 Probability = 0.7602, Class 1 Probability = 0.2398
# Sample 477: Class 0 Probability = 0.8053, Class 1 Probability = 0.1947
# Sample 478: Class 0 Probability = 0.9317, Class 1 Probability = 0.0683
# Sample 479: Class 0 Probability = 0.9372, Class 1 Probability = 0.0628
# Sample 480: Class 0 Probability = 0.9783, Class 1 Probability = 0.0217
# Sample 481: Class 0 Probability = 0.9260, Class 1 Probability = 0.0740
# Sample 482: Class 0 Probability = 0.9771, Class 1 Probability = 0.0229
# Sample 483: Class 0 Probability = 0.9233, Class 1 Probability = 0.0767
# Sample 484: Class 0 Probability = 0.8695, Class 1 Probability = 0.1305
# Sample 485: Class 0 Probability = 0.9810, Class 1 Probability = 0.0190
# Sample 486: Class 0 Probability = 0.5668, Class 1 Probability = 0.4332
# Sample 487: Class 0 Probability = 0.6083, Class 1 Probability = 0.3917
# Sample 488: Class 0 Probability = 0.8516, Class 1 Probability = 0.1484
# Sample 489: Class 0 Probability = 0.9204, Class 1 Probability = 0.0796
# Sample 490: Class 0 Probability = 0.9357, Class 1 Probability = 0.0643
# Sample 491: Class 0 Probability = 0.8781, Class 1 Probability = 0.1219
# Sample 492: Class 0 Probability = 0.9378, Class 1 Probability = 0.0622
# Sample 493: Class 0 Probability = 0.4953, Class 1 Probability = 0.5047
# Sample 494: Class 0 Probability = 0.9248, Class 1 Probability = 0.0752
# Sample 495: Class 0 Probability = 0.9197, Class 1 Probability = 0.0803
# Sample 496: Class 0 Probability = 0.9145, Class 1 Probability = 0.0855
# Sample 497: Class 0 Probability = 0.9783, Class 1 Probability = 0.0217
# Sample 498: Class 0 Probability = 0.2996, Class 1 Probability = 0.7004
# Sample 499: Class 0 Probability = 0.8589, Class 1 Probability = 0.1411
# Sample 500: Class 0 Probability = 0.9791, Class 1 Probability = 0.0209
# Sample 501: Class 0 Probability = 0.8583, Class 1 Probability = 0.1417
# Sample 502: Class 0 Probability = 0.9610, Class 1 Probability = 0.0390
# Sample 503: Class 0 Probability = 0.9003, Class 1 Probability = 0.0997
# Sample 504: Class 0 Probability = 0.9319, Class 1 Probability = 0.0681
# Sample 505: Class 0 Probability = 0.9813, Class 1 Probability = 0.0187
# Sample 506: Class 0 Probability = 0.9451, Class 1 Probability = 0.0549
# Sample 507: Class 0 Probability = 0.8674, Class 1 Probability = 0.1326
# Sample 508: Class 0 Probability = 0.9082, Class 1 Probability = 0.0918
# Sample 509: Class 0 Probability = 0.9194, Class 1 Probability = 0.0806
# Sample 510: Class 0 Probability = 0.9859, Class 1 Probability = 0.0141
# Sample 511: Class 0 Probability = 0.8084, Class 1 Probability = 0.1916
# Sample 512: Class 0 Probability = 0.9915, Class 1 Probability = 0.0085
# Sample 513: Class 0 Probability = 0.8328, Class 1 Probability = 0.1672
# Sample 514: Class 0 Probability = 0.9105, Class 1 Probability = 0.0895
# Sample 515: Class 0 Probability = 0.8880, Class 1 Probability = 0.1120
# Sample 516: Class 0 Probability = 0.9772, Class 1 Probability = 0.0228
# Sample 517: Class 0 Probability = 0.8711, Class 1 Probability = 0.1289
# Sample 518: Class 0 Probability = 0.9205, Class 1 Probability = 0.0795
# Sample 519: Class 0 Probability = 0.9261, Class 1 Probability = 0.0739
# Sample 520: Class 0 Probability = 0.9300, Class 1 Probability = 0.0700
# Sample 521: Class 0 Probability = 0.7768, Class 1 Probability = 0.2232
# Sample 522: Class 0 Probability = 0.9057, Class 1 Probability = 0.0943
# Sample 523: Class 0 Probability = 0.8187, Class 1 Probability = 0.1813
# Sample 524: Class 0 Probability = 0.9159, Class 1 Probability = 0.0841
# Sample 525: Class 0 Probability = 0.8782, Class 1 Probability = 0.1218
# Sample 526: Class 0 Probability = 0.9684, Class 1 Probability = 0.0316
# Sample 527: Class 0 Probability = 0.9753, Class 1 Probability = 0.0247
# Sample 528: Class 0 Probability = 0.8825, Class 1 Probability = 0.1175
# Sample 529: Class 0 Probability = 0.9660, Class 1 Probability = 0.0340
# Sample 530: Class 0 Probability = 0.9068, Class 1 Probability = 0.0932
# Sample 531: Class 0 Probability = 0.9306, Class 1 Probability = 0.0694
# Sample 532: Class 0 Probability = 0.7488, Class 1 Probability = 0.2512
# Sample 533: Class 0 Probability = 0.8220, Class 1 Probability = 0.1780
# Sample 534: Class 0 Probability = 0.9813, Class 1 Probability = 0.0187
# Sample 535: Class 0 Probability = 0.9092, Class 1 Probability = 0.0908
# Sample 536: Class 0 Probability = 0.8637, Class 1 Probability = 0.1363
# Sample 537: Class 0 Probability = 0.9251, Class 1 Probability = 0.0749
# Sample 538: Class 0 Probability = 0.8978, Class 1 Probability = 0.1022
# Sample 539: Class 0 Probability = 0.9642, Class 1 Probability = 0.0358
# Sample 540: Class 0 Probability = 0.9392, Class 1 Probability = 0.0608
# Sample 541: Class 0 Probability = 0.8710, Class 1 Probability = 0.1290
# Sample 542: Class 0 Probability = 0.9223, Class 1 Probability = 0.0777
# Sample 543: Class 0 Probability = 0.9368, Class 1 Probability = 0.0632
# Sample 544: Class 0 Probability = 0.8702, Class 1 Probability = 0.1298
# Sample 545: Class 0 Probability = 0.9580, Class 1 Probability = 0.0420
# Sample 546: Class 0 Probability = 0.5557, Class 1 Probability = 0.4443
# Sample 547: Class 0 Probability = 0.9368, Class 1 Probability = 0.0632
# Sample 548: Class 0 Probability = 0.9533, Class 1 Probability = 0.0467
# Sample 549: Class 0 Probability = 0.8184, Class 1 Probability = 0.1816
# Sample 550: Class 0 Probability = 0.9806, Class 1 Probability = 0.0194
# Sample 551: Class 0 Probability = 0.9351, Class 1 Probability = 0.0649
# Sample 552: Class 0 Probability = 0.9302, Class 1 Probability = 0.0698
# Sample 553: Class 0 Probability = 0.8507, Class 1 Probability = 0.1493
# Sample 554: Class 0 Probability = 0.9173, Class 1 Probability = 0.0827
# Sample 555: Class 0 Probability = 0.9733, Class 1 Probability = 0.0267
# Sample 556: Class 0 Probability = 0.8629, Class 1 Probability = 0.1371
# Sample 557: Class 0 Probability = 0.8615, Class 1 Probability = 0.1385
# Sample 558: Class 0 Probability = 0.9608, Class 1 Probability = 0.0392
# Sample 559: Class 0 Probability = 0.8627, Class 1 Probability = 0.1373
# Sample 560: Class 0 Probability = 0.9436, Class 1 Probability = 0.0564
# Sample 561: Class 0 Probability = 0.9654, Class 1 Probability = 0.0346
# Sample 562: Class 0 Probability = 0.9694, Class 1 Probability = 0.0306
# Sample 563: Class 0 Probability = 0.9292, Class 1 Probability = 0.0708
# Sample 564: Class 0 Probability = 0.8828, Class 1 Probability = 0.1172
# Sample 565: Class 0 Probability = 0.9757, Class 1 Probability = 0.0243
# Sample 566: Class 0 Probability = 0.7452, Class 1 Probability = 0.2548
# Sample 567: Class 0 Probability = 0.9483, Class 1 Probability = 0.0517
# Sample 568: Class 0 Probability = 0.4427, Class 1 Probability = 0.5573
# Sample 569: Class 0 Probability = 0.9034, Class 1 Probability = 0.0966
# Sample 570: Class 0 Probability = 0.9819, Class 1 Probability = 0.0181
# Sample 571: Class 0 Probability = 0.9285, Class 1 Probability = 0.0715
# Sample 572: Class 0 Probability = 0.9103, Class 1 Probability = 0.0897
# Sample 573: Class 0 Probability = 0.9428, Class 1 Probability = 0.0572
# Sample 574: Class 0 Probability = 0.9533, Class 1 Probability = 0.0467
# Sample 575: Class 0 Probability = 0.8924, Class 1 Probability = 0.1076
# Sample 576: Class 0 Probability = 0.9224, Class 1 Probability = 0.0776
# Sample 577: Class 0 Probability = 0.8892, Class 1 Probability = 0.1108
# Sample 578: Class 0 Probability = 0.8121, Class 1 Probability = 0.1879
# Sample 579: Class 0 Probability = 0.9917, Class 1 Probability = 0.0083
# Sample 580: Class 0 Probability = 0.9394, Class 1 Probability = 0.0606
# Sample 581: Class 0 Probability = 0.9297, Class 1 Probability = 0.0703
# Sample 582: Class 0 Probability = 0.9512, Class 1 Probability = 0.0488
# Sample 583: Class 0 Probability = 0.9788, Class 1 Probability = 0.0212
# Sample 584: Class 0 Probability = 0.9783, Class 1 Probability = 0.0217
# Sample 585: Class 0 Probability = 0.8830, Class 1 Probability = 0.1170
# Sample 586: Class 0 Probability = 0.8924, Class 1 Probability = 0.1076
# Sample 587: Class 0 Probability = 0.9249, Class 1 Probability = 0.0751
# Sample 588: Class 0 Probability = 0.9669, Class 1 Probability = 0.0331
# Sample 589: Class 0 Probability = 0.9514, Class 1 Probability = 0.0486
# Sample 590: Class 0 Probability = 0.8975, Class 1 Probability = 0.1025
# Sample 591: Class 0 Probability = 0.9697, Class 1 Probability = 0.0303
# Sample 592: Class 0 Probability = 0.9725, Class 1 Probability = 0.0275
# Sample 593: Class 0 Probability = 0.9077, Class 1 Probability = 0.0923
# Sample 594: Class 0 Probability = 0.9644, Class 1 Probability = 0.0356
# Sample 595: Class 0 Probability = 0.9379, Class 1 Probability = 0.0621
# Sample 596: Class 0 Probability = 0.8692, Class 1 Probability = 0.1308
# Sample 597: Class 0 Probability = 0.9477, Class 1 Probability = 0.0523
# Sample 598: Class 0 Probability = 0.9496, Class 1 Probability = 0.0504
# Sample 599: Class 0 Probability = 0.9789, Class 1 Probability = 0.0211
# Sample 600: Class 0 Probability = 0.9855, Class 1 Probability = 0.0145
# Sample 601: Class 0 Probability = 0.8748, Class 1 Probability = 0.1252
# Sample 602: Class 0 Probability = 0.8803, Class 1 Probability = 0.1197
# Sample 603: Class 0 Probability = 0.7350, Class 1 Probability = 0.2650
# Sample 604: Class 0 Probability = 0.9411, Class 1 Probability = 0.0589
# Sample 605: Class 0 Probability = 0.5723, Class 1 Probability = 0.4277
# Sample 606: Class 0 Probability = 0.9215, Class 1 Probability = 0.0785
# Sample 607: Class 0 Probability = 0.9909, Class 1 Probability = 0.0091
# Sample 608: Class 0 Probability = 0.6173, Class 1 Probability = 0.3827
# Sample 609: Class 0 Probability = 0.8998, Class 1 Probability = 0.1002
# Sample 610: Class 0 Probability = 0.9755, Class 1 Probability = 0.0245
# Sample 611: Class 0 Probability = 0.7908, Class 1 Probability = 0.2092
# Sample 612: Class 0 Probability = 0.8991, Class 1 Probability = 0.1009
# Sample 613: Class 0 Probability = 0.9664, Class 1 Probability = 0.0336
# Sample 614: Class 0 Probability = 0.8719, Class 1 Probability = 0.1281
# Sample 615: Class 0 Probability = 0.9445, Class 1 Probability = 0.0555
# Sample 616: Class 0 Probability = 0.9594, Class 1 Probability = 0.0406
# Sample 617: Class 0 Probability = 0.8789, Class 1 Probability = 0.1211
# Sample 618: Class 0 Probability = 0.8763, Class 1 Probability = 0.1237
# Sample 619: Class 0 Probability = 0.9246, Class 1 Probability = 0.0754
# Sample 620: Class 0 Probability = 0.7660, Class 1 Probability = 0.2340
# Sample 621: Class 0 Probability = 0.8554, Class 1 Probability = 0.1446
# Sample 622: Class 0 Probability = 0.9238, Class 1 Probability = 0.0762
# Sample 623: Class 0 Probability = 0.2966, Class 1 Probability = 0.7034
# Sample 624: Class 0 Probability = 0.6081, Class 1 Probability = 0.3919
# Sample 625: Class 0 Probability = 0.9521, Class 1 Probability = 0.0479
# Sample 626: Class 0 Probability = 0.7746, Class 1 Probability = 0.2254
# Sample 627: Class 0 Probability = 0.8915, Class 1 Probability = 0.1085
# Sample 628: Class 0 Probability = 0.7955, Class 1 Probability = 0.2045
# Sample 629: Class 0 Probability = 0.8859, Class 1 Probability = 0.1141
# Sample 630: Class 0 Probability = 0.8668, Class 1 Probability = 0.1332
# Sample 631: Class 0 Probability = 0.8481, Class 1 Probability = 0.1519
# Sample 632: Class 0 Probability = 0.9335, Class 1 Probability = 0.0665
# Sample 633: Class 0 Probability = 0.9391, Class 1 Probability = 0.0609
# Sample 634: Class 0 Probability = 0.9338, Class 1 Probability = 0.0662
# Sample 635: Class 0 Probability = 0.9051, Class 1 Probability = 0.0949
# Sample 636: Class 0 Probability = 0.8985, Class 1 Probability = 0.1015
# Sample 637: Class 0 Probability = 0.9126, Class 1 Probability = 0.0874
# Sample 638: Class 0 Probability = 0.9157, Class 1 Probability = 0.0843
# Sample 639: Class 0 Probability = 0.9048, Class 1 Probability = 0.0952
# Sample 640: Class 0 Probability = 0.9668, Class 1 Probability = 0.0332
# Sample 641: Class 0 Probability = 0.8952, Class 1 Probability = 0.1048
# Sample 642: Class 0 Probability = 0.6455, Class 1 Probability = 0.3545
# Sample 643: Class 0 Probability = 0.8716, Class 1 Probability = 0.1284
# Sample 644: Class 0 Probability = 0.8975, Class 1 Probability = 0.1025
# Sample 645: Class 0 Probability = 0.7853, Class 1 Probability = 0.2147
# Sample 646: Class 0 Probability = 0.9163, Class 1 Probability = 0.0837
# Sample 647: Class 0 Probability = 0.4644, Class 1 Probability = 0.5356
# Sample 648: Class 0 Probability = 0.9089, Class 1 Probability = 0.0911
# Sample 649: Class 0 Probability = 0.8527, Class 1 Probability = 0.1473
# Sample 650: Class 0 Probability = 0.9623, Class 1 Probability = 0.0377
# Sample 651: Class 0 Probability = 0.8373, Class 1 Probability = 0.1627
# Sample 652: Class 0 Probability = 0.9315, Class 1 Probability = 0.0685
# Sample 653: Class 0 Probability = 0.9468, Class 1 Probability = 0.0532
# Sample 654: Class 0 Probability = 0.9736, Class 1 Probability = 0.0264
# Sample 655: Class 0 Probability = 0.8868, Class 1 Probability = 0.1132
# Sample 656: Class 0 Probability = 0.8563, Class 1 Probability = 0.1437
# Sample 657: Class 0 Probability = 0.9815, Class 1 Probability = 0.0185
# Sample 658: Class 0 Probability = 0.8469, Class 1 Probability = 0.1531
# Sample 659: Class 0 Probability = 0.9280, Class 1 Probability = 0.0720
# Sample 660: Class 0 Probability = 0.9581, Class 1 Probability = 0.0419
# Sample 661: Class 0 Probability = 0.8532, Class 1 Probability = 0.1468
# Sample 662: Class 0 Probability = 0.9503, Class 1 Probability = 0.0497
# Sample 663: Class 0 Probability = 0.9036, Class 1 Probability = 0.0964
# Sample 664: Class 0 Probability = 0.9351, Class 1 Probability = 0.0649
# Sample 665: Class 0 Probability = 0.9035, Class 1 Probability = 0.0965
# Sample 666: Class 0 Probability = 0.7842, Class 1 Probability = 0.2158
# Sample 667: Class 0 Probability = 0.6752, Class 1 Probability = 0.3248
# Sample 668: Class 0 Probability = 0.7171, Class 1 Probability = 0.2829
# Sample 669: Class 0 Probability = 0.9599, Class 1 Probability = 0.0401
# Sample 670: Class 0 Probability = 0.8873, Class 1 Probability = 0.1127
# Sample 671: Class 0 Probability = 0.9494, Class 1 Probability = 0.0506
# Sample 672: Class 0 Probability = 0.9226, Class 1 Probability = 0.0774
# Sample 673: Class 0 Probability = 0.9513, Class 1 Probability = 0.0487
# Sample 674: Class 0 Probability = 0.8993, Class 1 Probability = 0.1007
# Sample 675: Class 0 Probability = 0.8902, Class 1 Probability = 0.1098
# Sample 676: Class 0 Probability = 0.9430, Class 1 Probability = 0.0570
# Sample 677: Class 0 Probability = 0.9622, Class 1 Probability = 0.0378
# ...
# Sample 8822: Class 0 Probability = 0.8991, Class 1 Probability = 0.1009
# Sample 8823: Class 0 Probability = 0.9286, Class 1 Probability = 0.0714
# Sample 8824: Class 0 Probability = 0.8753, Class 1 Probability = 0.1247
# Sample 8825: Class 0 Probability = 0.9370, Class 1 Probability = 0.0630
# Sample 8826: Class 0 Probability = 0.9353, Class 1 Probability = 0.0647
# Sample 8827: Class 0 Probability = 0.7130, Class 1 Probability = 0.2870
# Sample 8828: Class 0 Probability = 0.6179, Class 1 Probability = 0.3821
# Sample 8829: Class 0 Probability = 0.9527, Class 1 Probability = 0.0473
# Sample 8830: Class 0 Probability = 0.9078, Class 1 Probability = 0.0922
# Sample 8831: Class 0 Probability = 0.8115, Class 1 Probability = 0.1885
# Sample 8832: Class 0 Probability = 0.9652, Class 1 Probability = 0.0348
# Sample 8833: Class 0 Probability = 0.8255, Class 1 Probability = 0.1745
# Sample 8834: Class 0 Probability = 0.9365, Class 1 Probability = 0.0635
# Sample 8835: Class 0 Probability = 0.9293, Class 1 Probability = 0.0707
# Sample 8836: Class 0 Probability = 0.8943, Class 1 Probability = 0.1057
# Sample 8837: Class 0 Probability = 0.8988, Class 1 Probability = 0.1012
# Sample 8838: Class 0 Probability = 0.5785, Class 1 Probability = 0.4215
# Sample 8839: Class 0 Probability = 0.9675, Class 1 Probability = 0.0325
# Sample 8840: Class 0 Probability = 0.9730, Class 1 Probability = 0.0270
# Sample 8841: Class 0 Probability = 0.9558, Class 1 Probability = 0.0442
# Sample 8842: Class 0 Probability = 0.8845, Class 1 Probability = 0.1155
# Sample 8843: Class 0 Probability = 0.9248, Class 1 Probability = 0.0752
# Sample 8844: Class 0 Probability = 0.9817, Class 1 Probability = 0.0183
# Sample 8845: Class 0 Probability = 0.5828, Class 1 Probability = 0.4172
# Sample 8846: Class 0 Probability = 0.9700, Class 1 Probability = 0.0300
# Sample 9008: Class 0 Probability = 0.9097, Class 1 Probability = 0.0903
# Sample 9009: Class 0 Probability = 0.9264, Class 1 Probability = 0.0736
# Sample 9010: Class 0 Probability = 0.8826, Class 1 Probability = 0.1174
# Sample 9011: Class 0 Probability = 0.9195, Class 1 Probability = 0.0805
# Sample 9012: Class 0 Probability = 0.4873, Class 1 Probability = 0.5127
# Sample 9013: Class 0 Probability = 0.9632, Class 1 Probability = 0.0368
# Sample 9014: Class 0 Probability = 0.9914, Class 1 Probability = 0.0086
# Sample 9015: Class 0 Probability = 0.6587, Class 1 Probability = 0.3413
# Sample 9016: Class 0 Probability = 0.8254, Class 1 Probability = 0.1746
# Sample 9017: Class 0 Probability = 0.8809, Class 1 Probability = 0.1191
# Sample 9018: Class 0 Probability = 0.9692, Class 1 Probability = 0.0308
# Sample 9019: Class 0 Probability = 0.7302, Class 1 Probability = 0.2698
# Sample 9020: Class 0 Probability = 0.8526, Class 1 Probability = 0.1474
# Sample 9021: Class 0 Probability = 0.4865, Class 1 Probability = 0.5135
# Sample 9022: Class 0 Probability = 0.3666, Class 1 Probability = 0.6334
# Sample 9023: Class 0 Probability = 0.8726, Class 1 Probability = 0.1274
# Sample 9024: Class 0 Probability = 0.9216, Class 1 Probability = 0.0784
# Sample 9025: Class 0 Probability = 0.8795, Class 1 Probability = 0.1205
# Sample 9026: Class 0 Probability = 0.9753, Class 1 Probability = 0.0247
# Sample 9027: Class 0 Probability = 0.9062, Class 1 Probability = 0.0938
# Sample 9028: Class 0 Probability = 0.8704, Class 1 Probability = 0.1296
# Sample 9029: Class 0 Probability = 0.9498, Class 1 Probability = 0.0502
# Sample 9030: Class 0 Probability = 0.7255, Class 1 Probability = 0.2745
# Sample 9031: Class 0 Probability = 0.5342, Class 1 Probability = 0.4658
# Sample 9032: Class 0 Probability = 0.8561, Class 1 Probability = 0.1439
# Sample 9033: Class 0 Probability = 0.9426, Class 1 Probability = 0.0574
# Sample 9034: Class 0 Probability = 0.9771, Class 1 Probability = 0.0229
# Sample 9035: Class 0 Probability = 0.9887, Class 1 Probability = 0.0113
# Sample 9036: Class 0 Probability = 0.8867, Class 1 Probability = 0.1133
# Sample 9037: Class 0 Probability = 0.8427, Class 1 Probability = 0.1573
# Sample 9038: Class 0 Probability = 0.9759, Class 1 Probability = 0.0241
# Sample 9039: Class 0 Probability = 0.9704, Class 1 Probability = 0.0296
# Sample 9040: Class 0 Probability = 0.9469, Class 1 Probability = 0.0531
# Sample 9041: Class 0 Probability = 0.9258, Class 1 Probability = 0.0742
# Sample 9042: Class 0 Probability = 0.8734, Class 1 Probability = 0.1266
# Sample 9043: Class 0 Probability = 0.9387, Class 1 Probability = 0.0613

# %%
# Compare predictions with probability estimates
for i, (pred, prob, y) in enumerate(zip(preds, probabilities, y_test)):
    print(f"Sample {i+1}: Predicted Class = {pred}, True Class = {y} Class 0 Probability = {prob[0]:.4f}, Class 1 Probability = {prob[1]:.4f}")
# Out:
# Sample 1: Predicted Class = no, True Class = no Class 0 Probability = 0.9867, Class 1 Probability = 0.0133
# Sample 9026: Predicted Class = no, True Class = no Class 0 Probability = 0.9753, Class 1 Probability = 0.0247
# Sample 9027: Predicted Class = no, True Class = no Class 0 Probability = 0.9062, Class 1 Probability = 0.0938
# Sample 9028: Predicted Class = no, True Class = yes Class 0 Probability = 0.8704, Class 1 Probability = 0.1296
# Sample 9029: Predicted Class = no, True Class = no Class 0 Probability = 0.9498, Class 1 Probability = 0.0502
# Sample 9030: Predicted Class = no, True Class = yes Class 0 Probability = 0.7255, Class 1 Probability = 0.2745
# Sample 9031: Predicted Class = no, True Class = no Class 0 Probability = 0.5342, Class 1 Probability = 0.4658
# Sample 9032: Predicted Class = no, True Class = yes Class 0 Probability = 0.8561, Class 1 Probability = 0.1439
# Sample 9033: Predicted Class = no, True Class = no Class 0 Probability = 0.9426, Class 1 Probability = 0.0574
# Sample 9034: Predicted Class = no, True Class = no Class 0 Probability = 0.9771, Class 1 Probability = 0.0229
# Sample 9035: Predicted Class = no, True Class = no Class 0 Probability = 0.9887, Class 1 Probability = 0.0113
# Sample 9036: Predicted Class = no, True Class = no Class 0 Probability = 0.8867, Class 1 Probability = 0.1133
# Sample 9037: Predicted Class = no, True Class = no Class 0 Probability = 0.8427, Class 1 Probability = 0.1573
# Sample 9038: Predicted Class = no, True Class = no Class 0 Probability = 0.9759, Class 1 Probability = 0.0241
# Sample 9039: Predicted Class = no, True Class = no Class 0 Probability = 0.9704, Class 1 Probability = 0.0296
# Sample 9040: Predicted Class = no, True Class = no Class 0 Probability = 0.9469, Class 1 Probability = 0.0531
# Sample 9041: Predicted Class = no, True Class = no Class 0 Probability = 0.9258, Class 1 Probability = 0.0742
# Sample 9042: Predicted Class = no, True Class = no Class 0 Probability = 0.8734, Class 1 Probability = 0.1266
# Sample 9043: Predicted Class = no, True Class = no Class 0 Probability = 0.9387, Class 1 Probability = 0.0613

# %%
print(model_handler.model.classes_)
# Out:
# ['no' 'yes']

# %%
# We have the probabilities from predict_proba, therefore we can adjust threshold and make new predictions
threshold = 0.5
preds = []
for i, p in enumerate(probabilities):
    if p[1] >= threshold:
        preds.append('yes')
    else:
        preds.append('no')

# %%
precision, recall, thresholds = precision_recall_curve(y_test, probabilities[:, 1], pos_label="yes")
plt.figure()
plt.plot(recall, precision)
plt.xlabel("recall")
plt.ylabel("precision")
plt.show()

# %%
idx = np.argmin(np.abs(recall - 0.4))
print("Threshold:", thresholds[idx])
print("Precision:", precision[idx])
print("Recall:", recall[idx])
# Out:
# Threshold: 0.23660411522485295
# Precision: 0.5196560196560197
# Recall: 0.3998109640831758

# %%
res = model_handler.predict(probabilities, thresholds[idx])
conf_mtx = []
TP, TN, FP, FN = 0, 0, 0, 0
for y_hat, y in zip(res, y_test):
    if y_hat == "yes" and y == "yes":
        TP += 1
    elif y_hat == "yes" and y == "no":
        FP += 1
    elif y_hat == "no" and y == "yes":
        FN += 1
    else:
        TN += 1

conf_mtx = [TP, TN, FP, FN]
prec = TP / (TP + FP)
rec = TP / (TP + FN)
print(conf_mtx, prec, rec)
# Out:
# [423, 7594, 391, 635] 0.5196560196560197 0.3998109640831758

# %%
# This is a solid baseline, however moving threshold back and forth won't help our business. If we lower threshold we loose precision significantly, wasting business resources,
# meanwhile if we raise threshold, we loose potential customers. Next, I am going to try out decision tree to make hopefully better predictions.

# %%
f1_scorer = make_scorer(f1_score, pos_label="yes")
param_grid = {"max_depth": [3, 5, 7, 10, 15], "min_samples_leaf": [5, 10, 20, 50, 100]}

grid = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid=param_grid, scoring=f1_scorer, cv=5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'max_depth': [3, 5, 7, 10, 15],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring=make_scorer(f1_score, response_method='predict', pos_label=yes))

# %%
print(grid.best_params_)
print(grid.best_score_)
best_tree = grid.best_estimator_
# Out:
# {'max_depth': 15, 'min_samples_leaf': 10}
# 0.32133604017925144

# %%
tree_probs = best_tree.predict_proba(X_test)
best_tree.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
tree_precision, tree_recall, tree_thresholds = precision_recall_curve(
    y_test,
    tree_probs[:, 1],
    pos_label="yes"
)
plt.figure(figsize=(6, 4))

plt.plot(recall, precision, label="Logistic Regression")
plt.plot(tree_recall, tree_precision, label="Decision Tree")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

# %%
grid = GridSearchCV(RandomForestClassifier(random_state=42), param_grid=param_grid, scoring=f1_scorer, cv=5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [3, 5, 7, 10, 15],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring=make_scorer(f1_score, response_method='predict', pos_label=yes))

# %%
best_forest = grid.best_estimator_
forest_probs = best_forest.predict_proba(X_test)
best_forest.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
forest_precision, forest_recall, forest_thresholds = precision_recall_curve(
    y_test,
    forest_probs[:, 1],
    pos_label="yes"
)
plt.figure(figsize=(6, 4))

plt.plot(recall, precision, label="Logistic Regression")
plt.plot(tree_recall, tree_precision, label="Decision Tree")
plt.plot(forest_recall, forest_precision, label="Forest")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

# %%
# These outcomes show me a deeper issue with the features, so I need to revisit the dataset and my feature preprocessing.

# %%
# And yes... my assumption was right. I have several additional leaky features (bank-names.txt):
#   9 - contact: contact communication type (categorical: "unknown","telephone","cellular") 
#  10 - day: last contact day of the month (numeric)
#  11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#  12 - duration: last contact duration, in seconds (numeric)
   # other attributes:
#  13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)

# These are leaky features, because we don't know them in prediction time. They include the last contact information which in prediction time not known.

# %%
dataset = pd.read_csv("../bank-full.csv", sep=";")
seed = 42
test_size = 0.2
shuffle = True

for feature in ["duration", "contact", "day", "month", "campaign"]:
    dataset = dataset.drop(columns=[feature])

independent_variables = dataset.drop(columns=["y"])
dependent_variable = dataset["y"]
X_train, X_test, y_train, y_test = train_test_split(independent_variables, dependent_variable, random_state=seed, test_size=test_size, shuffle=shuffle, stratify=dependent_variable)
categorical_features = X_train.select_dtypes(include=["object", "str"]).columns
numerical_features = X_train.select_dtypes(include=["number"]).columns

for f in categorical_features:
    X_train, X_test = one_hot_encode_train_test(X_train=X_train, X_test=X_test, feature_name=str(f))

scales = {}
for f in ["age"]:
    X_train[f], mu, std = standard_scale(X_train[f])
    scales[f] = (mu, std)

for f in ["balance"]:
    X_train[f], median, iqr = robust_scale(X_train[f])
    scales[f] = (median, iqr)

for df in [X_train, X_test]:
    df["pdays"] = df["pdays"].replace(-1, 0)

for f in ["age"]:
    scale = scales[f]
    mu, std = scale[0], scale[1]
    X_test[f], _, _ = standard_scale(X_test[f], mu=mu, std=std)

for f in ["balance"]:
    scale = scales[f]
    median, iqr = scale[0], scale[1]
    X_test[f], _, _ = robust_scale(X_test[f], median=median, iqr=iqr)

X_train["previous"] = log_scale(X_train["previous"])
X_train["pdays"] = log_scale(X_train["pdays"])

X_test["previous"] = log_scale(X_test["previous"])
X_test["pdays"] = log_scale(X_test["pdays"])

# %%
model_handler = ModelHandler()
model_handler.model.fit(X_train, y_train)
probabilities_after_feature_removal = model_handler.model.predict_proba(X_test)
precision_clean, recall_clean, thresholds_clean = precision_recall_curve(y_test, probabilities_after_feature_removal[:, 1], pos_label="yes")

# %%
dataset = pd.read_csv("../bank-full.csv", sep=";")
seed = 42
test_size = 0.2
shuffle = True

for feature in ["duration"]:
    dataset = dataset.drop(columns=[feature])

independent_variables = dataset.drop(columns=["y"])
dependent_variable = dataset["y"]
X_train, X_test, y_train, y_test = train_test_split(independent_variables, dependent_variable, random_state=seed, test_size=test_size, shuffle=shuffle, stratify=dependent_variable)
categorical_features = X_train.select_dtypes(include=["object", "str"]).columns
numerical_features = X_train.select_dtypes(include=["number"]).columns

for f in categorical_features:
    X_train, X_test = one_hot_encode_train_test(X_train=X_train, X_test=X_test, feature_name=str(f))

scales = {}
for f in ["age"]:
    X_train[f], mu, std = standard_scale(X_train[f])
    scales[f] = (mu, std)

for f in ["balance"]:
    X_train[f], median, iqr = robust_scale(X_train[f])
    scales[f] = (median, iqr)

for df in [X_train, X_test]:
    df["pdays"] = df["pdays"].replace(-1, 0)

for f in ["age"]:
    scale = scales[f]
    mu, std = scale[0], scale[1]
    X_test[f], _, _ = standard_scale(X_test[f], mu=mu, std=std)

for f in ["balance"]:
    scale = scales[f]
    median, iqr = scale[0], scale[1]
    X_test[f], _, _ = robust_scale(X_test[f], median=median, iqr=iqr)

X_train["previous"] = log_scale(X_train["previous"])
X_train["pdays"] = log_scale(X_train["pdays"])

X_test["previous"] = log_scale(X_test["previous"])
X_test["pdays"] = log_scale(X_test["pdays"])

model_handler = ModelHandler()
model_handler.model.fit(X_train, y_train)
probabilities_after_feature_removal = model_handler.model.predict_proba(X_test)
precision_campaign, recall_campaign, thresholds_campaign = precision_recall_curve(y_test, probabilities_after_feature_removal[:, 1], pos_label="yes")
plt.plot(recall_clean, precision_clean, label="Pre-campaign features")
plt.plot(recall_campaign, precision_campaign, label="Current-campaign features included")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.show()

# %%
# This result shows us that the current campaign features performs better, because it contains the leaky features. These variables are unknown in prediction time, therefore 
# I am going to drop them during in the final train.py
